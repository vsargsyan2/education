# %%
import pandas as pd
from scipy.stats import f_oneway
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Данные по потреблению алкоголя (в зависимости от пола)
# В абсолютных значениях (хорошо бы узнать каких, но для поиска зависимостей подойдет)

# %%
alcohol = pd.read_csv("alcoholSubstanceAbuse.csv")
alcohol
# Out:
#          Location  Period                                          Indicator  \
# 0     Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 1     Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 2     Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 3     Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# 4     Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# ...           ...     ...                                                ...
# 2782     Zimbabwe    2005  Total (recorded+unrecorded) alcohol per capita...
# 2783     Zimbabwe    2005  Total (recorded+unrecorded) alcohol per capita...
# 2784     Zimbabwe    2000  Total (recorded+unrecorded) alcohol per capita...
# 2785     Zimbabwe    2000  Total (recorded+unrecorded) alcohol per capita...
# 2786     Zimbabwe    2000  Total (recorded+unrecorded) alcohol per capita...
#
#             Dim1  First Tooltip
# 0     Both sexes          0.210
# 1           Male          0.360
# 2         Female          0.055
# 3     Both sexes          0.210
# 4           Male          0.350
# ...          ...            ...
# 2782        Male          4.720
# 2783      Female          0.990
# 2784  Both sexes          2.460
# 2785        Male          4.160
# 2786      Female          0.880
#
# [2787 rows x 5 columns]

# %%
# возьмем усредненные данные для каждой страны с учетом пола
alcohol_mean = alcohol.groupby(['Location', 'Dim1'], as_index = False).agg({'First Tooltip': ['mean']})

# переименуем столбец
alcohol_mean['alcohol_per_capita'] = alcohol_mean['First Tooltip']
del alcohol_mean['First Tooltip']

# назначим страну индексом
alcohol_mean.set_index('Location', inplace = True)
alcohol_mean.rename(columns = {'Dim1' : 'sex'}, inplace = True)

# разделим наши данные. Сделаем три колонки по потреблению алкоголя у мужчин, женщин и обоих полов
alcohol_new = alcohol_mean[alcohol_mean['sex'] == 'Both sexes'].merge(
    alcohol_mean[alcohol_mean['sex'] == 'Male'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])
alcohol_new = alcohol_new.merge(
    alcohol_mean[alcohol_mean['sex'] == 'Female'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])

# переименуем столбцы
alcohol_new.rename(
    columns = {'alcohol_per_capita_x' : 'alcohol_per_capita_both', 
               'alcohol_per_capita_y' : 'alcohol_per_capita_male', 
               'alcohol_per_capita' : 'alcohol_per_capita_female'}, inplace = True)

# удалим лишние столбы с полом
alcohol_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True )
alcohol_new
# Out:
# C:\Users\Fosil\AppData\Local\Temp\ipykernel_30656\2765086347.py:27: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   alcohol_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True )
#                                    alcohol_per_capita_both  \
#
# Location
# Afghanistan                                         0.2100
# Albania                                             7.1640
# Algeria                                             0.7840
# Andorra                                            11.7940
# Angola                                              6.1420
# ...                                                    ...
# Venezuela (Bolivarian Republic of)                  7.6400
# Viet Nam                                            5.2520
# Yemen                                               0.2832
# Zambia                                              5.3620
# Zimbabwe                                            3.7500
#
#                                    alcohol_per_capita_male  \
#
# Location
# Afghanistan                                       0.356667
# Albania                                          11.606000
# Algeria                                           1.350000
# Andorra                                          18.198000
# Angola                                            9.768000
# ...                                                    ...
# Venezuela (Bolivarian Republic of)               12.102000
# Viet Nam                                          8.560000
# Yemen                                             0.488400
# Zambia                                            8.718000
# Zimbabwe                                          6.404000
#
#                                    alcohol_per_capita_female
#
# Location
# Afghanistan                                         0.054333
# Albania                                             2.730000
# Algeria                                             0.212000
# Andorra                                             5.690000
# Angola                                              2.744000
# ...                                                      ...
# Venezuela (Bolivarian Republic of)                  3.264000
# Viet Nam                                            2.116000
# Yemen                                               0.075200
# Zambia                                              2.144000
# Zimbabwe                                            1.322000
#
# [188 rows x 3 columns]

# %% [markdown]
# ### Данные по подростковой рождаемости
# Процент женщин, родивших в возрасте 15-19 лет

# %%
adolescent = pd.read_csv("adolescentBirthRate.csv")
# переведем в проценты
adolescent['First Tooltip'] = adolescent['First Tooltip']/10 
adolescent
# Out:
#          Location  Period                                          Indicator  \
# 0     Afghanistan    2017  Adolescent birth rate (per 1000 women aged 15-...
# 1     Afghanistan    2014  Adolescent birth rate (per 1000 women aged 15-...
# 2     Afghanistan    2013  Adolescent birth rate (per 1000 women aged 15-...
# 3     Afghanistan    2011  Adolescent birth rate (per 1000 women aged 15-...
# 4     Afghanistan    2009  Adolescent birth rate (per 1000 women aged 15-...
# ...           ...     ...                                                ...
# 2184     Zimbabwe    2008  Adolescent birth rate (per 1000 women aged 15-...
# 2185     Zimbabwe    2007  Adolescent birth rate (per 1000 women aged 15-...
# 2186     Zimbabwe    2004  Adolescent birth rate (per 1000 women aged 15-...
# 2187     Zimbabwe    2003  Adolescent birth rate (per 1000 women aged 15-...
# 2188     Zimbabwe    2002  Adolescent birth rate (per 1000 women aged 15-...
#
#       First Tooltip
# 0              6.20
# 1              7.72
# 2              8.70
# 3             12.57
# 4              8.00
# ...             ...
# 2184          11.20
# 2185          10.26
# 2186           9.87
# 2187          10.10
# 2188          10.26
#
# [2189 rows x 4 columns]

# %%
# возьмем усредненные данные для каждой страны
adolescent_new = adolescent.groupby(['Location']).agg({'First Tooltip': ['mean']})

# переименуем столбец
adolescent_new['%_adolescent_birth_rate'] = adolescent_new['First Tooltip']
del adolescent_new['First Tooltip']
adolescent_new
# Out:
#                                    %_adolescent_birth_rate
#
# Location
# Afghanistan                                      11.037273
# Albania                                           1.864706
# Algeria                                           0.885455
# Andorra                                           0.598421
# Angola                                           16.348333
# ...                                                    ...
# Venezuela (Bolivarian Republic of)                9.177692
# Viet Nam                                          3.109286
# Yemen                                             7.134000
# Zambia                                           14.578333
# Zimbabwe                                         10.588000
#
# [195 rows x 1 columns]

# %% [markdown]
# ### Количество самоубийств (в зависимости от пола)
# В процентах

# %%
suicide = pd.read_csv("crudeSuicideRates.csv")
suicide = suicide[suicide['Period'] != 2016]

# возьмем проценты
suicide['First Tooltip'] = suicide['First Tooltip']/1000
suicide
# Out:
#          Location  Period                                     Indicator  \
# 3     Afghanistan    2015  Crude suicide rates (per 100 000 population)
# 4     Afghanistan    2015  Crude suicide rates (per 100 000 population)
# 5     Afghanistan    2015  Crude suicide rates (per 100 000 population)
# 6     Afghanistan    2010  Crude suicide rates (per 100 000 population)
# 7     Afghanistan    2010  Crude suicide rates (per 100 000 population)
# ...           ...     ...                                           ...
# 2740     Zimbabwe    2005  Crude suicide rates (per 100 000 population)
# 2741     Zimbabwe    2005  Crude suicide rates (per 100 000 population)
# 2742     Zimbabwe    2000  Crude suicide rates (per 100 000 population)
# 2743     Zimbabwe    2000  Crude suicide rates (per 100 000 population)
# 2744     Zimbabwe    2000  Crude suicide rates (per 100 000 population)
#
#             Dim1  First Tooltip
# 3     Both sexes         0.0048
# 4           Male         0.0078
# 5         Female         0.0015
# 6     Both sexes         0.0051
# 7           Male         0.0086
# ...          ...            ...
# 2740        Male         0.0217
# 2741      Female         0.0064
# 2742  Both sexes         0.0129
# 2743        Male         0.0206
# 2744      Female         0.0055
#
# [2196 rows x 5 columns]

# %%
# возьмем усредненные данные для каждой страны с учетом пола
suicide_mean = suicide.groupby(['Location', 'Dim1'], as_index = False).agg({'First Tooltip': ['mean']})

# переименуем столбец
suicide_mean['%_suicide_rate'] = suicide_mean['First Tooltip']
del suicide_mean['First Tooltip']

# назначим страну индексом
suicide_mean.set_index('Location', inplace = True)
suicide_mean.rename(columns = {'Dim1' : 'sex'}, inplace = True)

# разделим наши данные. Сделаем три колонки по потреблению алкоголя у мужчин, женщин и обоих полов
suicide_new = suicide_mean[suicide_mean['sex'] == 'Both sexes'].merge(
    suicide_mean[suicide_mean['sex'] == 'Male'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])
suicide_new = suicide_new.merge(
    suicide_mean[suicide_mean['sex'] == 'Female'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])

# переименуем столбцы
suicide_new.rename(
    columns = {'%_suicide_rate_x' : '%_suicide_rate_both', 
               '%_suicide_rate_y' : '%_suicide_rate_male', 
               '%_suicide_rate' : '%_suicide_rate_female'}, inplace = True)

# удалим лишние столбы с полом
suicide_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True ) 
suicide_new
# Out:
# C:\Users\Fosil\AppData\Local\Temp\ipykernel_30656\3873885595.py:27: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   suicide_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True )
#                                    %_suicide_rate_both %_suicide_rate_male  \
#
# Location
# Afghanistan                                   0.005475            0.009300
# Albania                                       0.006500            0.008050
# Algeria                                       0.003600            0.005150
# Angola                                        0.006450            0.009775
# Antigua and Barbuda                           0.001075            0.001775
# ...                                                ...                 ...
# Venezuela (Bolivarian Republic of)            0.005500            0.009275
# Viet Nam                                      0.006900            0.010350
# Yemen                                         0.008075            0.010850
# Zambia                                        0.006750            0.009700
# Zimbabwe                                      0.012325            0.018975
#
#                                    %_suicide_rate_female
#
# Location
# Afghanistan                                     0.001350
# Albania                                         0.004925
# Algeria                                         0.002050
# Angola                                          0.003275
# Antigua and Barbuda                             0.000400
# ...                                                  ...
# Venezuela (Bolivarian Republic of)              0.001750
# Viet Nam                                        0.003600
# Yemen                                           0.005175
# Zambia                                          0.003875
# Zimbabwe                                        0.006000
#
# [184 rows x 3 columns]

# %% [markdown]
# ### Насилие по отношению к женщинам
# Процент женщин, которые хоть раз подвергались насилию со стороны нынешнего или бывшего партнера

# %%
violence_w = pd.read_csv("eliminateViolenceAgainstWomen.csv")
violence_w
# Out:
#         Location Period                                          Indicator  \
# 0    Afghanistan   2015  Proportion of ever-partnered women and girls a...
# 1    Afghanistan   2015  Proportion of ever-partnered women and girls a...
# 2    Afghanistan   2015  Proportion of ever-partnered women and girls a...
# 3    Afghanistan   2015  Proportion of ever-partnered women and girls a...
# 4    Afghanistan   2015  Proportion of ever-partnered women and girls a...
# ..           ...    ...                                                ...
# 553     Zimbabwe   2015  Proportion of ever-partnered women and girls a...
# 554     Zimbabwe   2015  Proportion of ever-partnered women and girls a...
# 555     Zimbabwe   2015  Proportion of ever-partnered women and girls a...
# 556     Zimbabwe   2015  Proportion of ever-partnered women and girls a...
# 557     Zimbabwe   2015  Proportion of ever-partnered women and girls a...
#
#        Dim1          Dim2  First Tooltip
# 0    Female  15-19  years           28.7
# 1    Female   20-24 years           41.1
# 2    Female   25-29 years           48.6
# 3    Female   30-34 years           49.3
# 4    Female   35-39 years           49.1
# ..      ...           ...            ...
# 553  Female   30-34 years           20.2
# 554  Female   35-39 years           15.7
# 555  Female   40-44 years           10.7
# 556  Female   15-49 years           19.9
# 557  Female   45-49 years           10.6
#
# [558 rows x 6 columns]

# %%
# берем средний показатель по странам
violence_w_new = violence_w.groupby(['Location']).agg({'First Tooltip': ['mean']})

#переименуем столбец
violence_w_new['%_w_got_abused'] = violence_w_new['First Tooltip']
del violence_w_new['First Tooltip']

violence_w_new
# Out:
#             %_w_got_abused
#
# Location
# Afghanistan        45.0000
# Angola             24.9625
# Armenia             3.0750
# Austria             4.0000
# Azerbaijan         10.1000
# ...                    ...
# Uruguay             2.8000
# Vanuatu            44.0000
# Viet Nam           11.4000
# Zambia             26.0250
# Zimbabwe           19.8250
#
# [107 rows x 1 columns]

# %% [markdown]
# ### Население, имеющее элементарные средства для мытья рук (для городов и деревень)
# Процент населения, имеющх доступ к базовым средствам

# %%
handwash = pd.read_csv("basicHandWashing.csv")
handwash
# Out:
#          Location                                          Indicator  Period  \
# 0     Afghanistan  Population with basic handwashing facilities a...    2017
# 1     Afghanistan  Population with basic handwashing facilities a...    2017
# 2     Afghanistan  Population with basic handwashing facilities a...    2017
# 3     Afghanistan  Population with basic handwashing facilities a...    2016
# 4     Afghanistan  Population with basic handwashing facilities a...    2016
# ...           ...                                                ...     ...
# 2721     Zimbabwe  Population with basic handwashing facilities a...    2012
# 2722     Zimbabwe  Population with basic handwashing facilities a...    2012
# 2723     Zimbabwe  Population with basic handwashing facilities a...    2011
# 2724     Zimbabwe  Population with basic handwashing facilities a...    2011
# 2725     Zimbabwe  Population with basic handwashing facilities a...    2011
#
#        Dim1  First Tooltip
# 0     Total          37.75
# 1     Urban          63.58
# 2     Rural          29.02
# 3     Total          37.67
# 4     Urban          63.58
# ...     ...            ...
# 2721  Urban          48.54
# 2722  Rural          31.20
# 2723  Total          36.93
# 2724  Urban          48.54
# 2725  Rural          31.20
#
# [2726 rows x 5 columns]

# %%
# берем средний показатель по странам
handwash_new = handwash.groupby(['Location']).agg({'First Tooltip': ['mean']})

# переименуем столбец
handwash_new['%_h_w_facilities'] = handwash_new['First Tooltip']
del handwash_new['First Tooltip']
handwash_new
# Out:
#             %_h_w_facilities
#
# Location
# Afghanistan        43.300256
# Algeria            81.438519
# Angola             24.492778
# Armenia            86.977037
# Azerbaijan         83.240000
# ...                      ...
# Vanuatu            30.261111
# Viet Nam           86.725385
# Yemen              52.377037
# Zambia             14.771250
# Zimbabwe           38.862381
#
# [97 rows x 1 columns]

# %% [markdown]
# ### Вероятность смерти от болезни (в зависимости от пола)
# Вероятность (в %) умереть в возрасте от 30 до 70 лет от любого сердечно-сосудистого заболевания, рака, диабета или хронического респираторного заболевания. Данные в зависимости от пола

# %%
prob_death = pd.read_csv("30-70cancerChdEtc.csv")
prob_death
# Out:
#          Location  Period                                          Indicator  \
# 0     Afghanistan    2016  Probability (%) of dying between age 30 and ex...
# 1     Afghanistan    2016  Probability (%) of dying between age 30 and ex...
# 2     Afghanistan    2016  Probability (%) of dying between age 30 and ex...
# 3     Afghanistan    2015  Probability (%) of dying between age 30 and ex...
# 4     Afghanistan    2015  Probability (%) of dying between age 30 and ex...
# ...           ...     ...                                                ...
# 2740     Zimbabwe    2005  Probability (%) of dying between age 30 and ex...
# 2741     Zimbabwe    2005  Probability (%) of dying between age 30 and ex...
# 2742     Zimbabwe    2000  Probability (%) of dying between age 30 and ex...
# 2743     Zimbabwe    2000  Probability (%) of dying between age 30 and ex...
# 2744     Zimbabwe    2000  Probability (%) of dying between age 30 and ex...
#
#             Dim1  First Tooltip
# 0     Both sexes           29.8
# 1           Male           31.8
# 2         Female           27.7
# 3     Both sexes           29.8
# 4           Male           31.9
# ...          ...            ...
# 2740        Male           22.1
# 2741      Female           22.9
# 2742  Both sexes           21.6
# 2743        Male           21.6
# 2744      Female           21.7
#
# [2745 rows x 5 columns]

# %%
# возьмем усредненные данные для каждой страны с учетом пола
prob_death_mean = prob_death.groupby(['Location', 'Dim1'], as_index = False).agg({'First Tooltip': ['mean']})

# переименуем столбец
prob_death_mean['%_death_probability'] = prob_death_mean['First Tooltip']
del prob_death_mean['First Tooltip']

# назначим страну индексом
prob_death_mean.set_index('Location', inplace = True)
prob_death_mean.rename(columns = {'Dim1' : 'sex'}, inplace = True)

# разделим наши данные. Сделаем три колонки по потреблению алкоголя у мужчин, женщин и обоих полов
prob_death_new = prob_death_mean[prob_death_mean['sex'] == 'Both sexes'].merge(
    prob_death_mean[prob_death_mean['sex'] == 'Male'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])
prob_death_new = prob_death_new.merge(
    prob_death_mean[prob_death_mean['sex'] == 'Female'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])

# переименуем столбцы
prob_death_new.rename(
    columns = {'%_death_probability_x' : '%_death_probability_both', 
               '%_death_probability_y' : '%_death_probability_male', 
               '%_death_probability' : '%_death_probability_female'}, inplace = True)

# удалим лишние столбы с полом
prob_death_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True ) 
prob_death_new
# Out:
# C:\Users\Fosil\AppData\Local\Temp\ipykernel_30656\3082505539.py:27: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prob_death_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True )
#                                    %_death_probability_both  \
#
# Location
# Afghanistan                                           31.96
# Albania                                               18.24
# Algeria                                               16.54
# Angola                                                19.36
# Antigua and Barbuda                                   22.36
# ...                                                     ...
# Venezuela (Bolivarian Republic of)                    19.14
# Viet Nam                                              17.88
# Yemen                                                 31.78
# Zambia                                                20.02
# Zimbabwe                                              20.78
#
#                                    %_death_probability_male  \
#
# Location
# Afghanistan                                           34.18
# Albania                                               21.82
# Algeria                                               17.80
# Angola                                                19.82
# Antigua and Barbuda                                   24.70
# ...                                                     ...
# Venezuela (Bolivarian Republic of)                    22.68
# Viet Nam                                              24.46
# Yemen                                                 34.38
# Zambia                                                19.82
# Zimbabwe                                              20.30
#
#                                    %_death_probability_female
#
# Location
# Afghanistan                                             29.72
# Albania                                                 14.26
# Algeria                                                 15.24
# Angola                                                  19.02
# Antigua and Barbuda                                     20.22
# ...                                                       ...
# Venezuela (Bolivarian Republic of)                      15.70
# Viet Nam                                                12.06
# Yemen                                                   29.28
# Zambia                                                  20.22
# Zimbabwe                                                21.16
#
# [184 rows x 3 columns]

# %% [markdown]
# ### Население, имеющее доступ к источникам воды
# Процент населения с доступом к хотя бы простейшим источникам воды

# %%
water = pd.read_csv("basicDrinkingWaterServices.csv")
water
# Out:
#          Location  Period                                          Indicator  \
# 0     Afghanistan    2017  Population using at least basic drinking-water...
# 1     Afghanistan    2016  Population using at least basic drinking-water...
# 2     Afghanistan    2015  Population using at least basic drinking-water...
# 3     Afghanistan    2014  Population using at least basic drinking-water...
# 4     Afghanistan    2013  Population using at least basic drinking-water...
# ...           ...     ...                                                ...
# 3450     Zimbabwe    2004  Population using at least basic drinking-water...
# 3451     Zimbabwe    2003  Population using at least basic drinking-water...
# 3452     Zimbabwe    2002  Population using at least basic drinking-water...
# 3453     Zimbabwe    2001  Population using at least basic drinking-water...
# 3454     Zimbabwe    2000  Population using at least basic drinking-water...
#
#       First Tooltip
# 0             57.32
# 1             54.84
# 2             52.39
# 3             49.96
# 4             47.56
# ...             ...
# 3450          57.94
# 3451          58.59
# 3452          59.23
# 3453          59.88
# 3454          59.88
#
# [3455 rows x 4 columns]

# %%
# берем среднее по странам
water_new = water.groupby(['Location']).agg({'First Tooltip': ['mean']})

# переименуем столбец
water_new['%_water'] = water_new['First Tooltip']
del water_new['First Tooltip']
water_new
# Out:
#                                        %_water
#
# Location
# Afghanistan                          37.755000
# Albania                              84.061667
# Algeria                              86.305000
# Andorra                             100.000000
# Angola                               24.313889
# ...                                        ...
# Venezuela (Bolivarian Republic of)   96.187778
# Viet Nam                             83.970556
# Yemen                                40.171667
# Zambia                               36.503889
# Zimbabwe                             55.077778
#
# [195 rows x 1 columns]

# %% [markdown]
# ### Уровень маледнческой смертности (в зависимости от пола)
# Вероятность смерти ребенка в возрасте до 1 года

# %%
infant_mortality = pd.read_csv("infantMortalityRate.csv")
infant_mortality['First Tooltip'] = infant_mortality['First Tooltip'].str.extract("([0-9]*\.[0-9]*)").astype(float)/10
infant_mortality
# Out:
#           Location  Period                                          Indicator  \
# 0      Afghanistan    2019  Infant mortality rate (probability of dying be...
# 1      Afghanistan    2019  Infant mortality rate (probability of dying be...
# 2      Afghanistan    2019  Infant mortality rate (probability of dying be...
# 3      Afghanistan    2018  Infant mortality rate (probability of dying be...
# 4      Afghanistan    2018  Infant mortality rate (probability of dying be...
# ...            ...     ...                                                ...
# 29994  Timor-Leste    2002  Infant mortality rate (probability of dying be...
# 29995  Timor-Leste    2002  Infant mortality rate (probability of dying be...
# 29996  Timor-Leste    2002  Infant mortality rate (probability of dying be...
# 29997  Timor-Leste    2001  Infant mortality rate (probability of dying be...
# 29998  Timor-Leste    2001  Infant mortality rate (probability of dying be...
#
#              Dim1  First Tooltip
# 0      Both sexes          4.651
# 1            Male          4.980
# 2          Female          4.305
# 3      Both sexes          4.804
# 4            Male          5.135
# ...           ...            ...
# 29994  Both sexes          7.708
# 29995        Male          8.253
# 29996      Female          7.137
# 29997  Both sexes          8.096
# 29998        Male          8.646
#
# [29999 rows x 5 columns]

# %%
# возьмем усредненные данные для каждой страны с учетом пола
infant_mortality_mean = infant_mortality.groupby(['Location', 'Dim1'], as_index = False).agg({'First Tooltip': ['mean']})

# переименуем столбец
infant_mortality_mean['%_infant_mortality'] = infant_mortality_mean['First Tooltip']
del infant_mortality_mean['First Tooltip']

# назначим страну индексом
infant_mortality_mean.set_index('Location', inplace = True)
infant_mortality_mean.rename(columns = {'Dim1' : 'sex'}, inplace = True)

# разделим наши данные. Сделаем три колонки по потреблению алкоголя у мужчин, женщин и обоих полов
infant_mortality_new = infant_mortality_mean[infant_mortality_mean['sex'] == 'Both sexes'].merge(
    infant_mortality_mean[infant_mortality_mean['sex'] == 'Male'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])
infant_mortality_new = infant_mortality_new.merge(
    infant_mortality_mean[infant_mortality_mean['sex'] == 'Female'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])

# переименуем столбцы
infant_mortality_new.rename(
    columns = {'%_infant_mortality_x' : '%_infant_mortality_both', 
               '%_infant_mortality_y' : '%_infant_mortality_male', 
               '%_infant_mortality' : '%_infant_mortality_female'}, inplace = True)

# удалим лишние столбы с полом
infant_mortality_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True ) 
infant_mortality_new
# Out:
# C:\Users\Fosil\AppData\Local\Temp\ipykernel_30656\1698902790.py:27: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   infant_mortality_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True )
#                                           %_infant_mortality_both  \
#
# Location
# Afghanistan                                             12.658931
# Albania                                                  2.912714
# Algeria                                                  7.807030
# Andorra                                                  0.623143
# Angola                                                  10.542400
# ...                                                           ...
# Syrian Arab Republic                                     5.252403
# Tajikistan                                               7.119479
# Thailand                                                 5.083643
# The former Yugoslav Republic of Macedonia                2.185744
# Timor-Leste                                              5.481947
#
#                                           %_infant_mortality_male  \
#
# Location
# Afghanistan                                             13.361759
# Albania                                                  3.262786
# Algeria                                                  8.192470
# Andorra                                                  0.687943
# Angola                                                  11.380725
# ...                                                           ...
# Syrian Arab Republic                                     5.499104
# Tajikistan                                               7.802979
# Thailand                                                 5.490229
# The former Yugoslav Republic of Macedonia                2.327769
# Timor-Leste                                              5.907158
#
#                                           %_infant_mortality_female
#
# Location
# Afghanistan                                               11.962983
# Albania                                                    2.543095
# Algeria                                                    7.473576
# Andorra                                                    0.554514
# Angola                                                     9.602200
# ...                                                             ...
# Syrian Arab Republic                                       5.049836
# Tajikistan                                                 6.439167
# Thailand                                                   4.638943
# The former Yugoslav Republic of Macedonia                  2.034103
# Timor-Leste                                                4.895389
#
# [177 rows x 3 columns]

# %% [markdown]
# ### Количество докторов
# Процент населения, работающих доктором

# %%
doctors = pd.read_csv("medicalDoctors.csv")
doctors['First Tooltip'] = doctors['First Tooltip']/100
doctors
# Out:
#          Location  Period                     Indicator  First Tooltip
# 0     Afghanistan    2016  Medical doctors (per 10,000)         0.0278
# 1     Afghanistan    2015  Medical doctors (per 10,000)         0.0285
# 2     Afghanistan    2014  Medical doctors (per 10,000)         0.0298
# 3     Afghanistan    2013  Medical doctors (per 10,000)         0.0285
# 4     Afghanistan    2012  Medical doctors (per 10,000)         0.0241
# ...           ...     ...                           ...            ...
# 2501     Zimbabwe    2005  Medical doctors (per 10,000)         0.0126
# 2502     Zimbabwe    2004  Medical doctors (per 10,000)         0.0174
# 2503     Zimbabwe    2000  Medical doctors (per 10,000)         0.0126
# 2504     Zimbabwe    1995  Medical doctors (per 10,000)         0.0143
# 2505     Zimbabwe    1990  Medical doctors (per 10,000)         0.0127
#
# [2506 rows x 4 columns]

# %%
# берем средние данные по странам
doctors_new = doctors.groupby(['Location']).agg({'First Tooltip': ['mean']})

# переименуем столбец
doctors_new['%_doctors'] = doctors_new['First Tooltip']
del doctors_new['First Tooltip']
doctors_new
# Out:
#                                    %_doctors
#
# Location
# Afghanistan                         0.023225
# Albania                             0.130927
# Algeria                             0.144500
# Andorra                             0.288400
# Angola                              0.011675
# ...                                      ...
# Venezuela (Bolivarian Republic of)  0.194800
# Viet Nam                            0.068800
# Yemen                               0.034840
# Zambia                              0.021030
# Zimbabwe                            0.012853
#
# [194 rows x 1 columns]

# %% [markdown]
# ### Курящее население (в зависимости от пола)
# Процент курящего населения (старше 15 лет)

# %%
tobacco15 = pd.read_csv("tobaccoAge15.csv")
tobacco15
# Out:
#       Location                                          Indicator  Period  \
# 0      Albania  Age-standardized prevalence of current tobacco...    2018
# 1      Albania  Age-standardized prevalence of current tobacco...    2018
# 2      Albania  Age-standardized prevalence of current tobacco...    2018
# 3      Albania  Age-standardized prevalence of current tobacco...    2017
# 4      Albania  Age-standardized prevalence of current tobacco...    2017
# ...        ...                                                ...     ...
# 4018  Zimbabwe  Age-standardized prevalence of current tobacco...    2005
# 4019  Zimbabwe  Age-standardized prevalence of current tobacco...    2005
# 4020  Zimbabwe  Age-standardized prevalence of current tobacco...    2000
# 4021  Zimbabwe  Age-standardized prevalence of current tobacco...    2000
# 4022  Zimbabwe  Age-standardized prevalence of current tobacco...    2000
#
#             Dim1  First Tooltip
# 0     Both sexes           29.2
# 1           Male           50.5
# 2         Female            7.9
# 3     Both sexes           29.3
# 4           Male           50.6
# ...          ...            ...
# 4018        Male           31.6
# 4019      Female            2.3
# 4020  Both sexes           18.3
# 4021        Male           33.7
# 4022      Female            2.9
#
# [4023 rows x 5 columns]

# %%
# возьмем усредненные данные для каждой страны с учетом пола
tobacco15_mean = tobacco15.groupby(['Location', 'Dim1'], as_index = False).agg({'First Tooltip': ['mean']})

# переименуем столбец
tobacco15_mean['%_tobacco'] = tobacco15_mean['First Tooltip']
del tobacco15_mean['First Tooltip']

# назначим страну индексом
tobacco15_mean.set_index('Location', inplace = True)
tobacco15_mean.rename(columns = {'Dim1' : 'sex'}, inplace = True)

# разделим наши данные. Сделаем три колонки по потреблению алкоголя у мужчин, женщин и обоих полов
tobacco15_new = tobacco15_mean[tobacco15_mean['sex'] == 'Both sexes'].merge(
    tobacco15_mean[tobacco15_mean['sex'] == 'Male'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])
tobacco15_new = tobacco15_new.merge(
    tobacco15_mean[tobacco15_mean['sex'] == 'Female'], 
    how = 'inner', left_on = ['Location'], right_on = ['Location'])

# переименуем столбцы
tobacco15_new.rename(
    columns = {'%_tobacco_x' : '%_tobacco_both', 
               '%_tobacco_y' : '%%_tobacco_male', 
               '%_tobacco' : '%_tobacco_female'}, inplace = True)

# удалим лишние столбы с полом
tobacco15_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True ) 
tobacco15_new
# Out:
# C:\Users\Fosil\AppData\Local\Temp\ipykernel_30656\2216665987.py:27: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   tobacco15_new.drop(['sex_x', 'sex_y', 'sex'], axis= 1 , inplace= True )
#            %_tobacco_both %%_tobacco_male %_tobacco_female
#
# Location
# Albania         30.722222       52.577778         8.855556
# Algeria         19.833333       38.011111         1.688889
# Andorra         34.511111       39.455556        29.544444
# Argentina       28.700000       35.555556        21.855556
# Armenia         29.244444       56.633333         1.855556
# ...                   ...             ...              ...
# Uzbekistan      13.466667       25.588889         1.322222
# Vanuatu         26.500000       49.200000         3.788889
# Yemen           23.833333       35.988889        11.666667
# Zambia          16.288889       27.200000         5.388889
# Zimbabwe        15.255556       28.777778         1.766667
#
# [149 rows x 3 columns]

# %%
# alcohol, adolescent, suicide, violence_w, handwash, prob_death, water, infant_mortality, doctors, tobacco15
who = prob_death_new.merge(alcohol_new,how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(tobacco15_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(water_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(handwash_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(doctors_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(suicide_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(adolescent_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(violence_w_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])
who = who.merge(infant_mortality_new, how = 'outer', left_on = ['Location'], right_on = ['Location'])

who
# Out:
#                                    %_death_probability_both  \
#
# Location
# Afghanistan                                           31.96
# Albania                                               18.24
# Algeria                                               16.54
# Angola                                                19.36
# Antigua and Barbuda                                   22.36
# ...                                                     ...
# State of Palestine                                      NaN
# Germany, Federal Republic (former)                      NaN
# India (until 1975)                                      NaN
# Kiribati (until 1984)                                   NaN
# South Viet Nam (former)                                 NaN
#
#                                    %_death_probability_male  \
#
# Location
# Afghanistan                                           34.18
# Albania                                               21.82
# Algeria                                               17.80
# Angola                                                19.82
# Antigua and Barbuda                                   24.70
# ...                                                     ...
# State of Palestine                                      NaN
# Germany, Federal Republic (former)                      NaN
# India (until 1975)                                      NaN
# Kiribati (until 1984)                                   NaN
# South Viet Nam (former)                                 NaN
#
#                                    %_death_probability_female  \
#
# Location
# Afghanistan                                             29.72
# Albania                                                 14.26
# Algeria                                                 15.24
# Angola                                                  19.02
# Antigua and Barbuda                                     20.22
# ...                                                       ...
# State of Palestine                                        NaN
# Germany, Federal Republic (former)                        NaN
# India (until 1975)                                        NaN
# Kiribati (until 1984)                                     NaN
# South Viet Nam (former)                                   NaN
#
#                                    alcohol_per_capita_both  \
#
# Location
# Afghanistan                                          0.210
# Albania                                              7.164
# Algeria                                              0.784
# Angola                                               6.142
# Antigua and Barbuda                                  5.674
# ...                                                    ...
# State of Palestine                                     NaN
# Germany, Federal Republic (former)                     NaN
# India (until 1975)                                     NaN
# Kiribati (until 1984)                                  NaN
# South Viet Nam (former)                                NaN
#
#                                    alcohol_per_capita_male  \
#
# Location
# Afghanistan                                       0.356667
# Albania                                          11.606000
# Algeria                                           1.350000
# Angola                                            9.768000
# Antigua and Barbuda                               9.160000
# ...                                                    ...
# State of Palestine                                     NaN
# Germany, Federal Republic (former)                     NaN
# India (until 1975)                                     NaN
# Kiribati (until 1984)                                  NaN
# South Viet Nam (former)                                NaN
#
#                                    alcohol_per_capita_female %_tobacco_both  \
#
# Location
# Afghanistan                                         0.054333            NaN
# Albania                                             2.730000      30.722222
# Algeria                                             0.212000      19.833333
# Angola                                              2.744000            NaN
# Antigua and Barbuda                                 2.572000            NaN
# ...                                                      ...            ...
# State of Palestine                                       NaN            NaN
# Germany, Federal Republic (former)                       NaN            NaN
# India (until 1975)                                       NaN            NaN
# Kiribati (until 1984)                                    NaN            NaN
# South Viet Nam (former)                                  NaN            NaN
#
#                                    %%_tobacco_male %_tobacco_female  \
#
# Location
# Afghanistan                                    NaN              NaN
# Albania                                  52.577778         8.855556
# Algeria                                  38.011111         1.688889
# Angola                                         NaN              NaN
# Antigua and Barbuda                            NaN              NaN
# ...                                            ...              ...
# State of Palestine                             NaN              NaN
# Germany, Federal Republic (former)             NaN              NaN
# India (until 1975)                             NaN              NaN
# Kiribati (until 1984)                          NaN              NaN
# South Viet Nam (former)                        NaN              NaN
#
#                                       %_water %_h_w_facilities %_doctors  \
#
# Location
# Afghanistan                         37.755000        43.300256  0.023225
# Albania                             84.061667              NaN  0.130927
# Algeria                             86.305000        81.438519  0.144500
# Angola                              24.313889        24.492778  0.011675
# Antigua and Barbuda                 97.328333              NaN  0.133950
# ...                                       ...              ...       ...
# State of Palestine                        NaN              NaN       NaN
# Germany, Federal Republic (former)        NaN              NaN       NaN
# India (until 1975)                        NaN              NaN       NaN
# Kiribati (until 1984)                     NaN              NaN       NaN
# South Viet Nam (former)                   NaN              NaN       NaN
#
#                                    %_suicide_rate_both %_suicide_rate_male  \
#
# Location
# Afghanistan                                   0.005475            0.009300
# Albania                                       0.006500            0.008050
# Algeria                                       0.003600            0.005150
# Angola                                        0.006450            0.009775
# Antigua and Barbuda                           0.001075            0.001775
# ...                                                ...                 ...
# State of Palestine                                 NaN                 NaN
# Germany, Federal Republic (former)                 NaN                 NaN
# India (until 1975)                                 NaN                 NaN
# Kiribati (until 1984)                              NaN                 NaN
# South Viet Nam (former)                            NaN                 NaN
#
#                                    %_suicide_rate_female  \
#
# Location
# Afghanistan                                     0.001350
# Albania                                         0.004925
# Algeria                                         0.002050
# Angola                                          0.003275
# Antigua and Barbuda                             0.000400
# ...                                                  ...
# State of Palestine                                   NaN
# Germany, Federal Republic (former)                   NaN
# India (until 1975)                                   NaN
# Kiribati (until 1984)                                NaN
# South Viet Nam (former)                              NaN
#
#                                    %_adolescent_birth_rate %_w_got_abused  \
#
# Location
# Afghanistan                                      11.037273        45.0000
# Albania                                           1.864706            NaN
# Algeria                                           0.885455            NaN
# Angola                                           16.348333        24.9625
# Antigua and Barbuda                               4.235714            NaN
# ...                                                    ...            ...
# State of Palestine                                5.084286            NaN
# Germany, Federal Republic (former)                     NaN            NaN
# India (until 1975)                                     NaN            NaN
# Kiribati (until 1984)                                  NaN            NaN
# South Viet Nam (former)                                NaN            NaN
#
#                                    %_infant_mortality_both  \
#
# Location
# Afghanistan                                      12.658931
# Albania                                           2.912714
# Algeria                                           7.807030
# Angola                                           10.542400
# Antigua and Barbuda                               2.576900
# ...                                                    ...
# State of Palestine                                     NaN
# Germany, Federal Republic (former)                1.469182
# India (until 1975)                               15.286364
# Kiribati (until 1984)                             9.475238
# South Viet Nam (former)                           5.405769
#
#                                    %_infant_mortality_male  \
#
# Location
# Afghanistan                                      13.361759
# Albania                                           3.262786
# Algeria                                           8.192470
# Angola                                           11.380725
# Antigua and Barbuda                               2.734257
# ...                                                    ...
# State of Palestine                                     NaN
# Germany, Federal Republic (former)                1.661864
# India (until 1975)                               15.850909
# Kiribati (until 1984)                            10.310095
# South Viet Nam (former)                           6.027538
#
#                                    %_infant_mortality_female
#
# Location
# Afghanistan                                        11.962983
# Albania                                             2.543095
# Algeria                                             7.473576
# Angola                                              9.602200
# Antigua and Barbuda                                 2.402243
# ...                                                      ...
# State of Palestine                                       NaN
# Germany, Federal Republic (former)                  1.267136
# India (until 1975)                                 15.070000
# Kiribati (until 1984)                               8.733571
# South Viet Nam (former)                             4.753538
#
# [200 rows x 20 columns]

# %%
f_oneway(prob_death_new['%_death_probability_male'], 
         prob_death_new['%_death_probability_female'], 
        prob_death_new['%_death_probability_both'])
# Out:
# F_onewayResult(statistic=45.241112462574755, pvalue=6.496680791946911e-19)
