# %%
import pandas as pd

# %%
world_cup = pd.read_csv('world_cup.csv')
world_cup[world_cup['Neutral Venue'] == False]
# Out:
#      Year        Date Home Team      Away Team  Home Score  Away Score  \
# 8    1930  1930-07-18   Uruguay           Peru         1.0         0.0
# 13   1930  1930-07-21   Uruguay        Romania         4.0         0.0
# 16   1930  1930-07-27   Uruguay     Yugoslavia         6.0         1.0
# 17   1930  1930-07-30   Uruguay      Argentina         4.0         2.0
# 24   1934  1934-05-27     Italy  United States         7.0         1.0
# ..    ...         ...       ...            ...         ...         ...
# 886  2018  2018-07-01    Russia          Spain         1.0         1.0
# 895  2018  2018-07-07    Russia        Croatia         2.0         2.0
# 900  2022  2022-11-20     Qatar        Ecuador         0.0         2.0
# 916  2022  2022-11-25     Qatar        Senegal         1.0         3.0
# 933  2022  2022-11-29     Qatar    Netherlands         0.0         2.0
#
#      Shootout      Tournament        City  Country  Neutral Venue  \
# ...
